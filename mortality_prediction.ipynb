# %%
'''
Script for Mortality prediction from ICU data 
Author : srinivasan@cs.toronto.edu
'''

import os
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
import numpy as np
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer

feature_max = {}
feature_min = {}
feature_mean = {}
feature_std = {}

def min_max_normalize(feature, feature_name, test=False):
    if not test:
        max_val = feature.max()
        min_val = feature.min()
        feature_max[feature_name] = max_val
        feature_min[feature_name] = min_val
    else:
        max_val = feature_max[feature_name]
        min_val = feature_min[feature_name]

    feature = (feature - min_val) / (max_val - min_val)
    return feature


def mean_std_normalize(feature, feature_name, test=False):
    if not test:
        mean = feature.mean()
        std = feature.std()
        feature_mean[feature_name] = mean
        feature_std[feature_name] = std
    else:
        mean = feature_mean[feature_name]
        std = feature_std[feature_name]

    feature = (feature - mean) / (std)
    return feature

def normalize_data(data, features, type='min_max', test=False):
    for feature in features:
        if type=='min_max':
            data[feature] = min_max_normalize(data[feature], feature, test)
        elif type=='mean_std':
            data[feature] = mean_std_normalize(data[feature], feature, test)
    return data

def predict_mortality():
    mimicdir = os.path.expanduser("~/Coursework/ML4Health/Assignment")
    data = pd.read_csv(os.path.join(mimicdir, 'adult_icu.gz'), compression='gzip')
    print(list(data))

    train_data = data.loc[data['train'] == 1]
    test_data = data.loc[data['train'] == 0]
    
    feature_cols = ['age', 'first_hosp_stay', 'first_icu_stay', 'adult_icu', 'eth_asian', 'eth_black', 'eth_hispanic', 'eth_other', 'eth_white', 'admType_ELECTIVE', 'admType_EMERGENCY', 'admType_NEWBORN', 'admType_URGENT',
     'heartrate_min', 'heartrate_max', 'heartrate_mean', 'sysbp_min', 
     'sysbp_max', 'sysbp_mean', 'diasbp_min', 'diasbp_max', 'diasbp_mean', 
     'meanbp_min', 'meanbp_max', 'meanbp_mean', 'resprate_min', 'resprate_max', 
     'resprate_mean', 'tempc_min', 'tempc_max', 'tempc_mean', 'spo2_min', 'spo2_max', 
     'spo2_mean', 'glucose_min', 'glucose_max', 'glucose_mean', 'aniongap', 'albumin', 
     'bicarbonate', 'bilirubin', 'creatinine','chloride', 'glucose', 'hematocrit', 
     'hemoglobin', 'lactate', 'magnesium', 'phosphate', 'platelet', 'potassium', 'ptt', 
     'inr', 'pt', 'sodium', 'bun', 'wbc']

    normalize_features = ['age', 'heartrate_min','heartrate_max','heartrate_mean', 'sysbp_min', 
     'sysbp_max', 'sysbp_mean', 'diasbp_min', 'diasbp_max', 'diasbp_mean', 
     'meanbp_min', 'meanbp_max', 'meanbp_mean', 'resprate_min', 'resprate_max', 
     'resprate_mean', 'tempc_min', 'tempc_max', 'tempc_mean', 'spo2_min', 'spo2_max', 
     'spo2_mean', 'glucose_min', 'glucose_max', 'glucose_mean','aniongap', 'albumin', 
     'bicarbonate', 'bilirubin', 'creatinine','chloride', 'glucose', 'hematocrit', 
     'hemoglobin', 'lactate', 'magnesium', 'phosphate', 'platelet', 'potassium','ptt', 
     'inr', 'pt', 'sodium', 'bun', 'wbc']
    mortality_target = ['mort_icu']

    train_X = train_data.loc[:,feature_cols]
    train_X = normalize_data(train_X, normalize_features,type='min_max', test=False)
    train_Y = train_data.loc[:,mortality_target]

    print(train_X.shape)
    print(train_Y.shape)

    test_X = test_data.loc[:,feature_cols]
    test_X = normalize_data(test_X, normalize_features,type='min_max', test=True)
    test_Y = test_data.loc[:,mortality_target]

    classifier = LogisticRegression(penalty='l2', C=1.0, random_state=0, solver='lbfgs', multi_class='ovr')
    classifier.fit(train_X, train_Y)
    W = classifier.coef_
    influence_weights = W.argsort(axis=-1)
    
    min_influence = influence_weights[0][0:5]
    max_influence = influence_weights[0][-5:][::-1]

    print(max_influence)
    print(np.array(feature_cols)[max_influence])
    print(np.array(feature_cols)[min_influence])
    print(np.array(feature_cols)[[27,46,7,29,10]])


    pred_Y = classifier.predict_proba(test_X)[:,1]
    print(pred_Y.shape)
    auc = roc_auc_score(test_Y, pred_Y)
    

    print(auc)

# %%
def predict_mortality_from_notes():
    mimicdir = os.path.expanduser("~/Coursework/ML4Health/Assignment")
    data = pd.read_csv(os.path.join(mimicdir, 'adult_notes.gz'), compression='gzip')
    print(list(data))

    train_data = data.loc[data['train'] == 1]
    test_data = data.loc[data['train'] == 0]
    train_data = data.loc[0:100]
    print(train_data)
    for i in range(0, train_data.shape[0]):
        text = train_data.iloc[i]['chartext']
        try:
            tokenizer = RegexpTokenizer(r'\w+')
            tokens = tokenizer.tokenize(text)
        except:
            tokens = ['test']
        stop = set(stopwords.words('english'))
        clean_tokens = [k for k in tokens if k not in stop]
        train_data = train_data.set_value(i,'chartext', (' ').join(clean_tokens))
    
    print(train_data)
    vectorizer = TfidfVectorizer()
    train_X = vectorizer.fit_transform(train_data.loc[:,'chartext'].values.astype('U'))
    train_Y = train_data.loc[:,'mort_icu']
    train_X = train_X.todense()
    
    classifier = LogisticRegression(penalty='l2', C=1.0, random_state=0, solver='lbfgs', multi_class='ovr')
    classifier.fit(train_X, train_Y)
    W = classifier.coef_
    influence_weights = W.argsort(axis=-1)

    for i in range(0, test_data.shape[0]):
        text = test_data.iloc[i]['chartext']
        try:
            tokenizer = RegexpTokenizer(r'\w+')
            tokens = tokenizer.tokenize(text)
        except:
            tokens = ['test']
        stop = set(stopwords.words('english'))
        clean_tokens = [i for i in tokens if i not in stop]
        test_data = test_data.set_value(i,'chartext', (' ').join(clean_tokens))

    test_X = vectorizer.transform(test_data.loc[:,'chartext'].values.astype('U'))
    test_Y = test_data.loc[:,'mort_icu'].values.astype('int')

    pred_Y = classifier.predict_proba(test_X)[:,1]
    print(pred_Y.shape)
    print(test_Y)
    auc = roc_auc_score(test_Y, pred_Y)
    
    print(auc)
    

if __name__ == '__main__':
    #predict_mortality()
    predict_mortality_from_notes()
# Out:
# ['subject_id', 'hadm_id', 'icustay_id', 'chartext', 'train', 'mort_icu']
#      subject_id  hadm_id  icustay_id  \
# 0             3   145834      211552
# 1             6   107064      228232
# 2             9   150750      220597
# 3            12   112213      232669
# 4            13   143045      263738
# 5            17   194023      277042
# 6            21   109451      217847
# 7            21   111970      216859
# 8            25   129635      203487
# 9            26   197661      244882
# 10           31   128652      254478
# 11           32   175413      295037
# 12           35   166707      282039
# 13           36   122659      211200
# 14           36   165660      241249
# 15           38   185910      248910
# 16           41   101757      237024
# 17           41   101757      261027
# 18           43   146828      225852
# 19           44   181750      291554
# 20           59   104130      224440
# 21           61   176332      252348
# 22           61   189535      217135
# 23           62   116009      216609
# 24           64   172056      232593
# 25           65   143430      244776
# 26           68   108329      272667
# 27           68   170467      294232
# 28           71   111944      211832
# 29           73   194730      284305
# ..          ...      ...         ...
# 71          138   188284      254974
# 72          140   165618      294530
# 73          141   168006      234668
# 74          143   143808      293406
# 75          144   137432      269520
# 76          145   138459      299479
# 77          145   198161      226841
# 78          145   198161      246376
# 79          146   190707      260172
# 80          147   103631      252947
# 81          148   199488      227964
# 82          150   108732      201239
# 83          152   117181      279643
# 84          154   102354      201272
# 85          154   162891      250579
# 86          156   168847      260696
# 87          156   199280      259092
# 88          157   107880      264885
# 89          157   110545      235058
# 90          161   121804      218407
# 91          164   182743      218740
# 92          170   175350      283077
# 93          171   153112      274684
# 94          174   110104      232160
# 95          177   143120      231756
# 96          177   143120      255303
# 97          177   143120      288571
# 98          177   196896      207706
# 99          178   196159      297704
# 100         179   161310      256090
#
#                                               chartext  train  mort_icu
# 0    [**2101-10-20**] 10:23 PM\n CHEST (PORTABLE AP...      1         0
# 1    Nursing Note:  see careview for complete detai...      1         0
# 2    [**2149-11-10**] 11:10 AM\n CHEST (PORTABLE AP...      1         1
# 3    Vent settings changed to Vt 600, Simv 16, Fio2...      1         0
# 4    Admission to CSRU\n39 y.o. admitted to CSRU af...      1         0
# 5    OP DAY MINIMALLY INVASIVE PFO REPAIR\nNSR. NO ...      1         0
# 6    CCU NPN\nPlease see carevue for all objective ...      0         0
# 7    [**2135-1-31**] 1:22 AM\n CHEST (PORTABLE AP) ...      1         1
# 8    CCU Nursing Progress Note-7a-7p\n58 y/o male a...      1         0
# 9    CCU NPN: Alt in CV\nS: "My foot is killing me,...      1         0
# 10   NPN MICU A (NSICU Pt.) 7p-7a\n\n72 yo male adm...      1         1
# 11   T/SICU Progress Note\nS/O: Neuro: Alert and or...      1         0
# 12   [**2122-2-11**] 2:18 AM\n CHEST (PORTABLE AP) ...      1         0
# 13   csru readmit\npt s/p cabg x5 4/ 27. readmit [*...      1         0
# 14   [**2134-5-13**] 11:07 AM\n CHEST (PORTABLE AP)...      1         0
# 15   Recieved pt from PACU at 1300- S/P I+D of scro...      0         0
# 16   nursing progress note\nneuro: a/o x3, answers ...      1         0
# 17   [**2133-1-3**] 11:12 AM\n CT CHEST W/CONTRAST;...      0         0
# 18   CCU NPN 1900-0700\nS: " I'm in so much pain- I...      1         0
# 19   RESPIRATORY CARE:\n\nPt weaned and extubated o...      0         0
# 20   NPN 7a-7p\nDNR\nPlease see carevue and fhp for...      1         0
# 21   [**2118-7-13**] 9:38 AM\n MRI ABDOMEN W/O & W/...      1         0
# 22   micu/sicu nsg note: 19:00-7:00\nevents: remain...      0         0
# 23   [**2113-2-15**] 8:14 AM\n CHEST (PORTABLE AP) ...      0         0
# 24   pmicu nursing progress note\nid:  pt's temp to...      1         0
# 25   [**2132-8-11**] 8:36 AM\n CT HEAD W/O CONTRAST...      1         0
# 26   respiratory care\npt was seen and treated with...      0         0
# 27   MICU/SICU NPN HD #2\nEvents: PICC line placed ...      1         0
# 28   [**2164-2-5**] 2:14 PM\n CT HEAD W/O CONTRAST ...      1         0
# 29   CCU-NPN\n\nNEURO: Pt. A&Ox3, follows commands ...      1         0
# ..                                                 ...    ...       ...
# 71   Addendum\nO: Neuro/ Pain mngment: med x 2 w 50...      1         0
# 72   MICU NURSING PROGRESS NOTE 0700-1900\nFOR NURS...      1         0
# 73   Patient remains on mechanical ventilation, tra...      1         1
# 74   condition update\nsee carevue for specifics:\n...      1         0
# 75   T/SICU NPN\nBrief ROS:\n[**Name (NI) **] Pt. i...      0         0
# 76   [**2145-2-15**] 6:02 PM\n CHEST PORT. LINE PLA...      0         0
# 77   CCU NPN 7P-7A\nS:"Help me, I'm going to be sic...      1         0
# 78   [**2144-4-22**] 10:27 PM\n CHEST (PORTABLE AP)...      1         0
# 79   [**2119-12-25**] 1:06 AM\n CHEST FLUORO WITHOU...      1         0
# 80   RESP CARE: pt recieved from OSH intubated with...      1         0
# 81   MSICU NPN 0700-1900\n\nInitially A&O x3. Tachy...      1         0
# 82   MICU NPN:\nNEURO: A&Ox3. No neuro deficits not...      1         0
# 83   NURSING NOTE 7A-7P Review of Systems;\nNEURO: ...      0         0
# 84                                                 NaN      1         0
# 85   7am-7pm update\nPt alert and oriented x3. MAE ...      1         0
# 86   NURSES NOTE 7a-7p\nEVENTS: Pt vomitted x1 @ 16...      1         0
# 87   [**2121-1-2**] 8:09 AM\n CHEST (PORTABLE AP)  ...      0         0
# 88   Resp: [**Name (NI) 257**] pt on a/c 15/400/+10...      1         0
# 89   [**2106-5-19**] 8:46 AM\n CT HEAD W/O CONTRAST...      1         0
# 90   NSG NOTE\nSEE FLOWSHEET FOR SPECIFICS.\n\nPT I...      1         0
# 91   [**2116-12-30**] 11:32 AM\n CHEST (PORTABLE AP...      1         1
# 92   Progress Note 7P-7a\n\nPatient continues to be...      1         0
# 93   [**2197-7-17**] 9:17 AM\n UK CATH CHECK       ...      1         0
# 94   [**Name8 (MD) 964**],rrt\npts, [**Name2 (NI) *...      1         1
# 95   ADMISSION NOTE\nPLEASE SEE FHP FOR DETAILS OF ...      0         0
# 96   MICU NPN 7pm-7am\n\n\nPt admitted [**12-2**] t...      0         0
# 97   NPN 8a-7p\n\nPt. admitted from [**Hospital War...      1         0
# 98   NURSING ADMISSION NOTE 1100-1500\nPT [**Name (...      1         0
# 99   NEURO:  [**Last Name (LF) **], [**First Name3 ...      0         0
# 100  (Continued)\n[**Last Name (un) 1019**] Levo to...      1         0
#
# [101 rows x 6 columns]
# /Users/srini/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:20: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#      subject_id  hadm_id  icustay_id  \
# 0             3   145834      211552
# 1             6   107064      228232
# 2             9   150750      220597
# 3            12   112213      232669
# 4            13   143045      263738
# 5            17   194023      277042
# 6            21   109451      217847
# 7            21   111970      216859
# 8            25   129635      203487
# 9            26   197661      244882
# 10           31   128652      254478
# 11           32   175413      295037
# 12           35   166707      282039
# 13           36   122659      211200
# 14           36   165660      241249
# 15           38   185910      248910
# 16           41   101757      237024
# 17           41   101757      261027
# 18           43   146828      225852
# 19           44   181750      291554
# 20           59   104130      224440
# 21           61   176332      252348
# 22           61   189535      217135
# 23           62   116009      216609
# 24           64   172056      232593
# 25           65   143430      244776
# 26           68   108329      272667
# 27           68   170467      294232
# 28           71   111944      211832
# 29           73   194730      284305
# ..          ...      ...         ...
# 71          138   188284      254974
# 72          140   165618      294530
# 73          141   168006      234668
# 74          143   143808      293406
# 75          144   137432      269520
# 76          145   138459      299479
# 77          145   198161      226841
# 78          145   198161      246376
# 79          146   190707      260172
# 80          147   103631      252947
# 81          148   199488      227964
# 82          150   108732      201239
# 83          152   117181      279643
# 84          154   102354      201272
# 85          154   162891      250579
# 86          156   168847      260696
# 87          156   199280      259092
# 88          157   107880      264885
# 89          157   110545      235058
# 90          161   121804      218407
# 91          164   182743      218740
# 92          170   175350      283077
# 93          171   153112      274684
# 94          174   110104      232160
# 95          177   143120      231756
# 96          177   143120      255303
# 97          177   143120      288571
# 98          177   196896      207706
# 99          178   196159      297704
# 100         179   161310      256090
#
#                                               chartext  train  mort_icu
# 0    2101 10 20 10 23 PM CHEST PORTABLE AP Clip Cli...      1         0
# 1    Nursing Note see careview complete details Nue...      1         0
# 2    2149 11 10 11 10 AM CHEST PORTABLE AP Clip Cli...      1         1
# 3    Vent settings changed Vt 600 Simv 16 Fio2 50 P...      1         0
# 4    Admission CSRU 39 admitted CSRU CABG x 3 LIMA ...      1         0
# 5    OP DAY MINIMALLY INVASIVE PFO REPAIR NSR NO EC...      1         0
# 6    CCU NPN Please see carevue objective data neur...      0         0
# 7    2135 1 31 1 22 AM CHEST PORTABLE AP Clip Clip ...      1         1
# 8    CCU Nursing Progress Note 7a 7p 58 male admitt...      1         0
# 9    CCU NPN Alt CV S My foot killing I ignore I th...      1         0
# 10   NPN MICU A NSICU Pt 7p 7a 72 yo male admitted ...      1         1
# 11   T SICU Progress Note S O Neuro Alert oriented ...      1         0
# 12   2122 2 11 2 18 AM CHEST PORTABLE AP Clip Clip ...      1         0
# 13   csru readmit pt p cabg x5 4 27 readmit 5 13 un...      1         0
# 14   2134 5 13 11 07 AM CHEST PORTABLE AP Clip Clip...      1         0
# 15   Recieved pt PACU 1300 S P I D scrotum worsenin...      0         0
# 16   nursing progress note neuro x3 answers appropr...      1         0
# 17   2133 1 3 11 12 AM CT CHEST W CONTRAST CT 100CC...      0         0
# 18   CCU NPN 1900 0700 S I much pain I feel full ga...      1         0
# 19   RESPIRATORY CARE Pt weaned extubated overnight...      0         0
# 20   NPN 7a 7p DNR Please see carevue fhp additiona...      1         0
# 21   2118 7 13 9 38 AM MRI ABDOMEN W O W CONTRAST M...      1         0
# 22   micu sicu nsg note 19 00 7 00 events remains l...      0         0
# 23   2113 2 15 8 14 AM CHEST PORTABLE AP Clip Clip ...      0         0
# 24   pmicu nursing progress note id pt temp today 1...      1         0
# 25   2132 8 11 8 36 AM CT HEAD W O CONTRAST Clip Cl...      1         0
# 26   respiratory care pt seen treated 5mg albuteral...      0         0
# 27   MICU SICU NPN HD 2 Events PICC line placed L2 ...      1         0
# 28   2164 2 5 2 14 PM CT HEAD W O CONTRAST Clip Cli...      1         0
# 29   CCU NPN NEURO Pt A Ox3 follows commands approp...      1         0
# ..                                                 ...    ...       ...
# 71   Addendum O Neuro Pain mngment med x 2 w 50 mcg...      1         0
# 72   MICU NURSING PROGRESS NOTE 0700 1900 FOR NURSI...      1         0
# 73   Patient remains mechanical ventilation transfu...      1         1
# 74   condition update see carevue specifics neuro a...      1         0
# 75   T SICU NPN Brief ROS Name NI Pt awake today in...      0         0
# 76   2145 2 15 6 02 PM CHEST PORT LINE PLACEMENT 77...      0         0
# 77   CCU NPN 7P 7A S Help I going sick O Please see...      1         0
# 78   2144 4 22 10 27 PM CHEST PORTABLE AP Clip Clip...      1         0
# 79   2119 12 25 1 06 AM CHEST FLUORO WITHOUT RADIOL...      1         0
# 80   RESP CARE pt recieved OSH intubated 7 5ETT 24 ...      1         0
# 81   MSICU NPN 0700 1900 Initially A O x3 Tachypnea...      1         0
# 82   MICU NPN NEURO A Ox3 No neuro deficits noted M...      1         0
# 83   NURSING NOTE 7A 7P Review Systems NEURO Sleepi...      0         0
# 84                                                test      1         0
# 85   7am 7pm update Pt alert oriented x3 MAE sponta...      1         0
# 86   NURSES NOTE 7a 7p EVENTS Pt vomitted x1 1630 H...      1         0
# 87   2121 1 2 8 09 AM CHEST PORTABLE AP Clip Clip N...      0         0
# 88   Resp Name NI 257 pt c 15 400 10 50 Bs clear bi...      1         0
# 89   2106 5 19 8 46 AM CT HEAD W O CONTRAST Clip Cl...      1         0
# 90   NSG NOTE SEE FLOWSHEET FOR SPECIFICS PT IS A 7...      1         0
# 91   2116 12 30 11 32 AM CHEST PORTABLE AP Clip Cli...      1         1
# 92   Progress Note 7P 7a Patient continues intubate...      1         0
# 93   2197 7 17 9 17 AM UK CATH CHECK Clip Clip Numb...      1         0
# 94   Name8 MD 964 rrt pts Name2 NI 23 8 left Last N...      1         1
# 95   ADMISSION NOTE PLEASE SEE FHP FOR DETAILS OF P...      0         0
# 96   MICU NPN 7pm 7am Pt admitted 12 2 MICU p resp ...      0         0
# 97   NPN 8a 7p Pt admitted Hospital Ward Name 7 res...      1         0
# 98   NURSING ADMISSION NOTE 1100 1500 PT Name NI 98...      1         0
# 99   NEURO Last Name LF First Name3 LF 55 follows c...      0         0
# 100  Continued Last Name un 1019 Levo maintain MAP ...      1         0
#
# [101 rows x 6 columns]
# /Users/srini/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:42: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/srini/anaconda2/lib/python2.7/site-packages/pandas/core/frame.py:2587: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.loc[index, col] = value
# (9990,)
# [                   0                    0                    0 ...,
#  -9223372036854775808 -9223372036854775808 -9223372036854775808]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-b282907e8756> in <module>()
#      55 if __name__ == '__main__':
#      56     #predict_mortality()
# ---> 57     predict_mortality_from_notes()
#
# <ipython-input-2-b282907e8756> in predict_mortality_from_notes()
#      48     print(pred_Y.shape)
#      49     print(test_Y)
# ---> 50     auc = roc_auc_score(test_Y, pred_Y)
#      51
#      52     print(auc)
#
# /Users/srini/anaconda2/lib/python2.7/site-packages/sklearn/metrics/ranking.pyc in roc_auc_score(y_true, y_score, average, sample_weight)
#     275     return _average_binary_score(
#     276         _binary_roc_auc_score, y_true, y_score, average,
# --> 277         sample_weight=sample_weight)
#     278
#     279
#
# /Users/srini/anaconda2/lib/python2.7/site-packages/sklearn/metrics/base.pyc in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      70     y_type = type_of_target(y_true)
#      71     if y_type not in ("binary", "multilabel-indicator"):
# ---> 72         raise ValueError("{0} format is not supported".format(y_type))
#      73
#      74     if y_type == "binary":
#
# ValueError: multiclass format is not supported

# %%
mimicdir = os.path.expanduser("~/Coursework/ML4Health/Assignment")
data = pd.read_csv(os.path.join(mimicdir, 'adult_notes.gz'), compression='gzip')
print(list(data))

train_data = data.loc[data['train'] == 1]
test_data = data.loc[data['train'] == 0]
train_data = train_data[0:100]

print(train_data)
for i in range(0, train_data.shape[0]):
    text = train_data.iloc[i]['chartext']
    try:
        tokenizer = RegexpTokenizer(r'\w+')
        tokens = tokenizer.tokenize(text)
    except:
        tokens = ['test']
    stop = set(stopwords.words('english'))
    clean_tokens = [k for k in tokens if k not in stop]
    train_data = train_data.set_value(i,'chartext', (' ').join(clean_tokens))

print(train_data)
vectorizer = TfidfVectorizer()
train_X = vectorizer.fit_transform(train_data.loc[:,'chartext'].values.astype('U'))
train_Y = train_data.loc[:,['mort_icu']]
train_X = train_X.todense()

classifier = LogisticRegression(penalty='l2', C=1.0, random_state=0, solver='lbfgs', multi_class='ovr')
classifier.fit(train_X, train_Y)
W = classifier.coef_
influence_weights = W.argsort(axis=-1)

for i in range(0, test_data.shape[0]):
    text = test_data.iloc[i]['chartext']
    try:
        tokenizer = RegexpTokenizer(r'\w+')
        tokens = tokenizer.tokenize(text)
    except:
        tokens = ['test']
    stop = set(stopwords.words('english'))
    clean_tokens = [i for i in tokens if i not in stop]
    test_data = test_data.set_value(i,'chartext', (' ').join(clean_tokens))

test_X = vectorizer.transform(test_data.loc[:,'chartext'].values.astype('U'))
test_Y = test_data.loc[:,['mort_icu']]

pred_Y = classifier.predict_proba(test_X)[:,1]
print(pred_Y.shape)
print(test_Y)
auc = roc_auc_score(test_Y, pred_Y)

print(auc)
# Out:
# ['subject_id', 'hadm_id', 'icustay_id', 'chartext', 'train', 'mort_icu']
#      subject_id  hadm_id  icustay_id  \
# 0             3   145834      211552
# 1             6   107064      228232
# 2             9   150750      220597
# 3            12   112213      232669
# 4            13   143045      263738
# 5            17   194023      277042
# 7            21   111970      216859
# 8            25   129635      203487
# 9            26   197661      244882
# 10           31   128652      254478
# 11           32   175413      295037
# 12           35   166707      282039
# 13           36   122659      211200
# 14           36   165660      241249
# 16           41   101757      237024
# 18           43   146828      225852
# 20           59   104130      224440
# 21           61   176332      252348
# 24           64   172056      232593
# 25           65   143430      244776
# 27           68   170467      294232
# 28           71   111944      211832
# 29           73   194730      284305
# 31           83   158569      254066
# 33           91   121205      256972
# 34           94   140037      213450
# 35           96   170324      211943
# 37           98   188606      216929
# 38           99   187373      251343
# 40          101   175533      233111
# ..          ...      ...         ...
# 100         179   161310      256090
# 103         188   123860      213646
# 105         188   132401      292343
# 106         188   164735      284015
# 107         191   136614      280149
# 108         191   142081      285720
# 109         195   118936      266038
# 110         195   118936      291941
# 111         198   131286      251887
# 112         199   125590      235675
# 114         203   120358      244420
# 115         205   135671      277536
# 117         209   135807      206719
# 118         209   190711      229904
# 120         211   193975      270493
# 121         212   189635      274498
# 125         221   189243      247500
# 126         222   103002      256144
# 128         222   188038      260665
# 129         223   105694      231395
# 133         228   167764      235332
# 135         231   198608      242685
# 137         234   188399      252814
# 138         236   151459      259718
# 139         238   174168      208413
# 140         241   177846      259962
# 141         243   129066      241533
# 142         245   105501      216674
# 144         249   116935      215044
# 150         256   153771      296823
#
#                                               chartext  train  mort_icu
# 0    [**2101-10-20**] 10:23 PM\n CHEST (PORTABLE AP...      1         0
# 1    Nursing Note:  see careview for complete detai...      1         0
# 2    [**2149-11-10**] 11:10 AM\n CHEST (PORTABLE AP...      1         1
# 3    Vent settings changed to Vt 600, Simv 16, Fio2...      1         0
# 4    Admission to CSRU\n39 y.o. admitted to CSRU af...      1         0
# 5    OP DAY MINIMALLY INVASIVE PFO REPAIR\nNSR. NO ...      1         0
# 7    [**2135-1-31**] 1:22 AM\n CHEST (PORTABLE AP) ...      1         1
# 8    CCU Nursing Progress Note-7a-7p\n58 y/o male a...      1         0
# 9    CCU NPN: Alt in CV\nS: "My foot is killing me,...      1         0
# 10   NPN MICU A (NSICU Pt.) 7p-7a\n\n72 yo male adm...      1         1
# 11   T/SICU Progress Note\nS/O: Neuro: Alert and or...      1         0
# 12   [**2122-2-11**] 2:18 AM\n CHEST (PORTABLE AP) ...      1         0
# 13   csru readmit\npt s/p cabg x5 4/ 27. readmit [*...      1         0
# 14   [**2134-5-13**] 11:07 AM\n CHEST (PORTABLE AP)...      1         0
# 16   nursing progress note\nneuro: a/o x3, answers ...      1         0
# 18   CCU NPN 1900-0700\nS: " I'm in so much pain- I...      1         0
# 20   NPN 7a-7p\nDNR\nPlease see carevue and fhp for...      1         0
# 21   [**2118-7-13**] 9:38 AM\n MRI ABDOMEN W/O & W/...      1         0
# 24   pmicu nursing progress note\nid:  pt's temp to...      1         0
# 25   [**2132-8-11**] 8:36 AM\n CT HEAD W/O CONTRAST...      1         0
# 27   MICU/SICU NPN HD #2\nEvents: PICC line placed ...      1         0
# 28   [**2164-2-5**] 2:14 PM\n CT HEAD W/O CONTRAST ...      1         0
# 29   CCU-NPN\n\nNEURO: Pt. A&Ox3, follows commands ...      1         0
# 31   Nursing note 7pm-7am\nPt underwent right carot...      1         0
# 33   MICU/SICU NURSING PROGRESS NOTE.\n     Sedated...      1         1
# 34   Respiratory care:\nPatient remians intubated a...      1         0
# 35   [**2156-3-31**] 5:43 PM\n CT HEAD W/O CONTRAST...      1         0
# 37   [**2137-4-3**] 11:17 AM\n CAROT/CEREB [**Hospi...      1         0
# 38   neuro. alert and awake. sl. anxious re pain. m...      1         0
# 40   Respiratory Care\nRemains intubated and ventil...      1         0
# ..                                                 ...    ...       ...
# 100  (Continued)\n[**Last Name (un) 1019**] Levo to...      1         0
# 103  [**2161-1-2**] 4:54 AM\n CHEST (PORTABLE AP)  ...      1         0
# 105  [**2162-1-11**] 5:40 PM\n CHEST (PORTABLE AP);...      1         0
# 106  [**2161-7-2**] 8:15 PM\n CHEST (PORTABLE AP); ...      1         0
# 107  Nurse Progress Note 0700-1900\n\nEvents: NSR c...      1         0
# 108  MICU nursing progress note 7A-7P\nResp - Recei...      1         0
# 109  ADMIT FROM [**Hospital Ward Name 57**] 2\nPT A...      1         0
# 110  [**2167-12-2**] 4:29 PM\n CHEST (PORTABLE AP) ...      1         0
# 111  please see flow sheet for full assessment and ...      1         0
# 112  Coronary artery bypass graft (CABG)\n   Assess...      1         0
# 114  npn 7-7am\n\nPt was transitioned from nipride ...      1         0
# 115  CCU NURSING PROGRESS NOTE\nS/O:  PT IS A 75 YO...      1         0
# 117  [**2119-9-26**] 3:30 PM\n CHEST (PORTABLE AP) ...      1         0
# 118  [**2127-8-12**] 5:06 PM\n CHEST (PORTABLE AP) ...      1         0
# 120  csru update\ncvs: bp labile. nitro restarted f...      1         0
# 121  NURSING NOTE\nPLEASE SEE CAREVUE FOR DETAILS\n...      1         0
# 125  [**2103-12-10**] 10:28 AM\n CT HEAD W/O CONTRA...      1         0
# 126  Chief Complaint:  Shortness of breath\n   HPI:...      1         0
# 128  Micu nursing note [**5-/2034**]\n\nNeuro:pt is...      1         0
# 129  CSRU NPN\nNEURO: A/OX3. YELLS OUT "WATER, WATE...      1         0
# 133  [**2132-11-1**] 7:48 AM\n CHEST (PORTABLE AP) ...      1         0
# 135  [**2176-5-30**] 11:33 AM\n CHEST (PORTABLE AP)...      1         0
# 137  CCU Nursing Progress Note\nS:  I've got some i...      1         0
# 138  [**2134-10-4**] 1:23 PM\n PORTABLE ABDOMEN    ...      1         0
# 139  C/O NAUSEA GIVEN REGLAN IV EFFECTIVE. MED W/ P...      1         0
# 140  Respiratory Care\nPt intubated on ventilatory ...      1         0
# 141  [**2140-2-17**] 11:38 AM\n CHEST (PORTABLE AP)...      1         0
# 142  [**2172-7-8**] 12:11 PM\n PORTABLE ABDOMEN    ...      1         1
# 144  Resp Care: Pt adm from floor with hypercarbic ...      1         0
# 150  [**2166-7-23**] 8:55 AM\n CHEST (PORTABLE AP) ...      1         0
#
# [100 rows x 6 columns]
# /Users/srini/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:19: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#     subject_id   hadm_id  icustay_id  \
# 0          3.0  145834.0    211552.0
# 1          6.0  107064.0    228232.0
# 2          9.0  150750.0    220597.0
# 3         12.0  112213.0    232669.0
# 4         13.0  143045.0    263738.0
# 5         17.0  194023.0    277042.0
# 7         21.0  111970.0    216859.0
# 8         25.0  129635.0    203487.0
# 9         26.0  197661.0    244882.0
# 10        31.0  128652.0    254478.0
# 11        32.0  175413.0    295037.0
# 12        35.0  166707.0    282039.0
# 13        36.0  122659.0    211200.0
# 14        36.0  165660.0    241249.0
# 16        41.0  101757.0    237024.0
# 18        43.0  146828.0    225852.0
# 20        59.0  104130.0    224440.0
# 21        61.0  176332.0    252348.0
# 24        64.0  172056.0    232593.0
# 25        65.0  143430.0    244776.0
# 27        68.0  170467.0    294232.0
# 28        71.0  111944.0    211832.0
# 29        73.0  194730.0    284305.0
# 31        83.0  158569.0    254066.0
# 33        91.0  121205.0    256972.0
# 34        94.0  140037.0    213450.0
# 35        96.0  170324.0    211943.0
# 37        98.0  188606.0    216929.0
# 38        99.0  187373.0    251343.0
# 40       101.0  175533.0    233111.0
# ..         ...       ...         ...
# 6          NaN       NaN         NaN
# 15         NaN       NaN         NaN
# 17         NaN       NaN         NaN
# 19         NaN       NaN         NaN
# 22         NaN       NaN         NaN
# 23         NaN       NaN         NaN
# 26         NaN       NaN         NaN
# 30         NaN       NaN         NaN
# 32         NaN       NaN         NaN
# 36         NaN       NaN         NaN
# 39         NaN       NaN         NaN
# 41         NaN       NaN         NaN
# 43         NaN       NaN         NaN
# 47         NaN       NaN         NaN
# 48         NaN       NaN         NaN
# 54         NaN       NaN         NaN
# 56         NaN       NaN         NaN
# 60         NaN       NaN         NaN
# 61         NaN       NaN         NaN
# 63         NaN       NaN         NaN
# 65         NaN       NaN         NaN
# 67         NaN       NaN         NaN
# 68         NaN       NaN         NaN
# 75         NaN       NaN         NaN
# 76         NaN       NaN         NaN
# 83         NaN       NaN         NaN
# 87         NaN       NaN         NaN
# 95         NaN       NaN         NaN
# 96         NaN       NaN         NaN
# 99         NaN       NaN         NaN
#
#                                              chartext  train  mort_icu
# 0   2101 10 20 10 23 PM CHEST PORTABLE AP Clip Cli...    1.0       0.0
# 1   Nursing Note see careview complete details Nue...    1.0       0.0
# 2   2149 11 10 11 10 AM CHEST PORTABLE AP Clip Cli...    1.0       1.0
# 3   Vent settings changed Vt 600 Simv 16 Fio2 50 P...    1.0       0.0
# 4   Admission CSRU 39 admitted CSRU CABG x 3 LIMA ...    1.0       0.0
# 5   OP DAY MINIMALLY INVASIVE PFO REPAIR NSR NO EC...    1.0       0.0
# 7   CCU Nursing Progress Note 7a 7p 58 male admitt...    1.0       1.0
# 8   CCU NPN Alt CV S My foot killing I ignore I th...    1.0       0.0
# 9   NPN MICU A NSICU Pt 7p 7a 72 yo male admitted ...    1.0       0.0
# 10  T SICU Progress Note S O Neuro Alert oriented ...    1.0       1.0
# 11  2122 2 11 2 18 AM CHEST PORTABLE AP Clip Clip ...    1.0       0.0
# 12  csru readmit pt p cabg x5 4 27 readmit 5 13 un...    1.0       0.0
# 13  2134 5 13 11 07 AM CHEST PORTABLE AP Clip Clip...    1.0       0.0
# 14  nursing progress note neuro x3 answers appropr...    1.0       0.0
# 16  NPN 7a 7p DNR Please see carevue fhp additiona...    1.0       0.0
# 18  pmicu nursing progress note id pt temp today 1...    1.0       0.0
# 20  MICU SICU NPN HD 2 Events PICC line placed L2 ...    1.0       0.0
# 21  2164 2 5 2 14 PM CT HEAD W O CONTRAST Clip Cli...    1.0       0.0
# 24  MICU SICU NURSING PROGRESS NOTE Sedated unresp...    1.0       0.0
# 25  Respiratory care Patient remians intubated mec...    1.0       0.0
# 27  2137 4 3 11 17 AM CAROT CEREB Hospital1 Clip C...    1.0       0.0
# 28  neuro alert awake sl anxious pain med X 2 perc...    1.0       0.0
# 29  Respiratory Care Remains intubated ventilated ...    1.0       0.0
# 31  Chief Complaint HPI 24 Hour Events DIALYSIS CA...    1.0       0.0
# 33  Demographics Day intubation Day mechanical ven...    1.0       1.0
# 34  TITLE Ms Known lastname 406 24 year old woman ...    1.0       0.0
# 35  23 F h Lupus ESRD HD planned PD labile hyperte...    1.0       0.0
# 37  Last Name LF First Name8 NamePattern2 Last Nam...    1.0       0.0
# 38  NPN 7p 7a Full Code Please see carevue FHP add...    1.0       0.0
# 40  2142 7 14 7 57 AM CHEST PORTABLE AP Clip Clip ...    1.0       0.0
# ..                                                ...    ...       ...
# 6   2135 1 31 1 22 AM CHEST PORTABLE AP Clip Clip ...    NaN       NaN
# 15  CCU NPN 1900 0700 S I much pain I feel full ga...    NaN       NaN
# 17  2118 7 13 9 38 AM MRI ABDOMEN W O W CONTRAST M...    NaN       NaN
# 19  2132 8 11 8 36 AM CT HEAD W O CONTRAST Clip Cl...    NaN       NaN
# 22  CCU NPN NEURO Pt A Ox3 follows commands approp...    NaN       NaN
# 23  Nursing note 7pm 7am Pt underwent right caroti...    NaN       NaN
# 26  2156 3 31 5 43 PM CT HEAD W O CONTRAST Clip Cl...    NaN       NaN
# 30  Nursing Progress Note Events Pt 2 episodes pre...    NaN       NaN
# 32  NPN 7p 7a Neuro Pt intubated sedated change sh...    NaN       NaN
# 36  24yo F SLE ESRD HD malignant hypertension pres...    NaN       NaN
# 39  2137 11 11 5 37 AM CHEST PORTABLE AP Clip Clip...    NaN       NaN
# 41  2142 4 26 6 00 AM CHEST PORTABLE AP Clip Clip ...    NaN       NaN
# 43  2166 1 10 9 24 PM PORTABLE ABDOMEN Clip Clip N...    NaN       NaN
# 47  SICU Nursing Progress Note Neuro Pt Name NI x3...    NaN       NaN
# 48  Addendum O Neuro Pain mngment med x 2 w 50 mcg...    NaN       NaN
# 54  2119 12 25 1 06 AM CHEST FLUORO WITHOUT RADIOL...    NaN       NaN
# 56  MSICU NPN 0700 1900 Initially A O x3 Tachypnea...    NaN       NaN
# 60  NURSES NOTE 7a 7p EVENTS Pt vomitted x1 1630 H...    NaN       NaN
# 61  Resp Name NI 257 pt c 15 400 10 50 Bs clear bi...    NaN       NaN
# 63  NSG NOTE SEE FLOWSHEET FOR SPECIFICS PT IS A 7...    NaN       NaN
# 65  Progress Note 7P 7a Patient continues intubate...    NaN       NaN
# 67  Name8 MD 964 rrt pts Name2 NI 23 8 left Last N...    NaN       NaN
# 68  NPN 8a 7p Pt admitted Hospital Ward Name 7 res...    NaN       NaN
# 75  MICU nursing progress note 7A 7P Resp Received...    NaN       NaN
# 76  ADMIT FROM Hospital Ward Name 57 2 PT ADMIT FR...    NaN       NaN
# 83  2127 8 12 5 06 PM CHEST PORTABLE AP Clip Clip ...    NaN       NaN
# 87  Chief Complaint Shortness breath HPI Ms Name14...    NaN       NaN
# 95  Respiratory Care Pt intubated ventilatory supp...    NaN       NaN
# 96  2140 2 17 11 38 AM CHEST PORTABLE AP Clip Clip...    NaN       NaN
# 99  2166 7 23 8 55 AM CHEST PORTABLE AP Clip Clip ...    NaN       NaN
#
# [130 rows x 6 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-a3776cadf923> in <module>()
#      26
#      27 classifier = LogisticRegression(penalty='l2', C=1.0, random_state=0, solver='lbfgs', multi_class='ovr')
# ---> 28 classifier.fit(train_X, train_Y)
#      29 W = classifier.coef_
#      30 influence_weights = W.argsort(axis=-1)
#
# /Users/srini/anaconda2/lib/python2.7/site-packages/sklearn/linear_model/logistic.pyc in fit(self, X, y, sample_weight)
#    1221
#    1222         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype,
# -> 1223                          order="C")
#    1224         check_classification_targets(y)
#    1225         self.classes_ = np.unique(y)
#
# /Users/srini/anaconda2/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     577     else:
#     578         y = column_or_1d(y, warn=True)
# --> 579         _assert_all_finite(y)
#     580     if y_numeric and y.dtype.kind == 'O':
#     581         y = y.astype(np.float64)
#
# /Users/srini/anaconda2/lib/python2.7/site-packages/sklearn/utils/validation.pyc in _assert_all_finite(X)
#      42             and not np.isfinite(X).all()):
#      43         raise ValueError("Input contains NaN, infinity"
# ---> 44                          " or a value too large for %r." % X.dtype)
#      45
#      46
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
print(test_X.shape)
print(test_Y.shape)
print(data.shape)
print(train_data.shape)
print(test_data.shape)
# Out:
# (9990, 10474)
# (9990, 1)
# (27348, 6)
# (101, 6)
# (9990, 6)
